# %%
from Bio import Phylo
import pylab
import matplotlib
import matplotlib.pyplot as plt
from Bio import Phylo
from io import StringIO

# %%
# 1. read the output tree

# %%
input_tree = Phylo.read("../linked_dir/kianabehesht17-podarcis-2022-02-16/outputs_pg_2145tree5952/labelled_pg_2145tree5952.tre","newick")

# %%
input_tree.ladderize()
Phylo.draw(input_tree)

# %%
matplotlib.rc('font', size=6)
    # set the size of the figure
fig = plt.figure(figsize=(10, 30), dpi=300)
    # alternatively
    # fig.set_size_inches(10, 40)
axes = fig.add_subplot(3, 1, 1)
Phylo.draw(input_tree, axes=axes, do_show=False)
pylab.axis('off')
output_file = "Kiana's Podarcis results.pdf"
plt.savefig(output_file, dpi=300)

# %%
Phylo.draw_ascii(input_tree)
# Out:
#   ___ Xantusia_vigilis_otu315920
#  |
#  | ____ Rhacodactylus_trachyrhynchus_otu315940
#  ||
#  ||______ Eublepharis_macularius_otu315941
#  |
#  | _______________ Sphenodon_punctatus_otu315924
#  ||
#  ||   ______ Ramphotyphlops_bicolor_otu315934
#  ||__|
#  |   |    _ Dinodon_semicarinatum_otu315925
#  |   |___|
#  |       |___ Ovophis_okinavensis_otu315938
#  |
#  |      _ Crotaphytus_collaris_otu315922
#  |     |
#  |     |________ Smaug_warreni_otu315928
# _|     |
#  |     |__ Gambelia_wislizenii_otu315919
#  |     |
#  |     |_____ Sceloporus_virgatus_otu315926
#  |     |
#  |     |       , Anelytropsis_papillosus_otu315944
#  |     |_______|
#  |     |       |_ Dibamus_sp._MCB-2004_otu315923
#  |     |
#  |     |     __ Plestiodon_egregius_otu315927
#  |     |____|
#  |     |    |__ Iguana_iguana_otu315921
#  |     |
#  |     |          __ Amphisbaena_schmidti_otu315942
#  |     |_________|
#  |     |         | ______ Geocalamus_acutus_otu315931
#  |     |         ||
#  |_____|          |_______ Bipes_canaliculatus_otu315935
#        |
#        |             __________ Pogona_vitticeps_otu315918
#        |____________|
#        |            |         ____ Chamaeleo_africanus_otu315939
#        |            |________|
#        |                     |_ Furcifer_labordi_otu315945
#        |
#        |    ___ Shinisaurus_crocodilurus_otu315917
#        |___|
#        |   |  ________ Varanus_komodoensis_otu315936
#        |   |_|
#        |     | __ Abronia_graminea_otu315930
#        |     ||
#        |      |_ Xenosaurus_platyceps_otu315933
#        |
#        |               __ Ameiva_plei_otu315946
#        |       _______|
#        |      |       |_____ Gymnophthalmus_speciosus_otu315929
#        |      |
#        |______| __ Atlantolacerta_andreanskyi_otu315937
#               ||
#               ||______ Acanthodactylus_erythrurus_otu315943
#               ||
#               ||  , Podarcis_vaucheri_otuPS89
#                |  |
#                |  , Podarcis_hispanicus_otuPS88
#                |__|
#                   , Podarcis_hispanicus_otuPS84
#                   |
#                   | Podarcis_hispanicus_otuPS87
#                   |
#                   , Podarcis_sp._Jbel_Siroua_lineage_otuPS86
#                   |
#                   | Podarcis_sp._Jbel_Siroua_lineage_otuPS85
#                   |
#                   , Podarcis_hispanica_otu315932
#                   |
#                   , Podarcis_hispanicus_otuPS83
#                   |
#                   | Podarcis_sp._Jbel_Siroua_lineage_otuPS81

# %%
# !ls
# Out:
# Kiana's Podarcis Challenge.ipynb challenge.ipynb
# Kiana's Podarcis results.pdf     podarcis_output_tree.pdf
# README.md

# %%
# !pwd
# Out:
# /Users/luciabazan/collab-paper/jupyter-notebooks

# %%
# !ls ../linked_dir/kianabehesht17-podarcis-2022-03-02/run_pg_2145tree5952/
# Out:
# RAxML_bestTree.2022-03-02
# RAxML_bootstrap.BOOT2022-03-02
# RAxML_info.2022-03-02
# RAxML_info.BOOT2022-03-02
# RAxML_log.2022-03-02
# RAxML_result.2022-03-02
# all_align_pg_2145tree5952.fas
# boot_summary.tre
# logfile
# muscle.log
# new_seqs_UNaligned_2022-03-02_pg_2145tree5952.fas
# new_seqs_aligned_2022-03-02_pg_2145tree5952.fas
# original_cleaned.fas
# original_pg_2145tree5952.fas
# otu_info_pg_2145tree5952.json
# physcraper_pg_2145tree5952.fas
# random_resolve.tre
# run.config

# %%
# !ls ../linked_dir/kianabehesht17-podarcis-2022-02-16/outputs_pg_2145tree5952/labelled_pg_2145tree5952.tre
# Out:
# ../linked_dir/kianabehesht17-podarcis-2022-02-16/outputs_pg_2145tree5952/labelled_pg_2145tree5952.tre

# %%
# 2. plot the tree
# Hint: use the print function from BioPython


# 3. save the plot as pdf
# Hints:
# use the functions figure(), savefig() and show() from matplotlib.pyplot
# and the function Phylo.draw() from BioPython
